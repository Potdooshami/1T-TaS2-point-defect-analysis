# %% [markdown]
# <a href="https://colab.research.google.com/github/Potdooshami/1T-TaS2-point-defect-analysis/blob/master/DAY2_PYMAIA7.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 인공지능 수학 기초

# %% [markdown]
# "The limits of my language mean the limits of my world."
# 언어를 모르고선 올바른 질문조차 할 수 없다.

# %% [markdown]
# 미분

# %% [markdown]
# 행렬

# %% [markdown]
# # 최적화

# %% [markdown]
# 경사하강법

# %% [markdown]
# 과적합 과소적합

# %% [markdown]
# 트레이닝-테스트 데이터 분할

# %% [markdown]
# # SLP

# %% [markdown]
# 붓꽃 데이터셋

# %% [markdown]
# 다변수 예측

# %% [markdown]
# 다중분류

# %% [markdown]
# 행렬표현식

# %% [markdown]
# 신경망 표현식

# %% [markdown]
# 선형 클래시파이어로 분류 안 되는 경우

# %% [markdown]
# 타이타닉데이터셋으로 뭔가를 해보자
